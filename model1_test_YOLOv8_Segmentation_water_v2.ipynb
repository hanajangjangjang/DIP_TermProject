# %%
from ultralytics import YOLO
import os
from pathlib import Path
import time
import json
import numpy as np
import cv2

# 載入訓練好的模型
model_path = r"C:\Users\hanaj\Desktop\HanaJ\Lab\YOLOgroundtruth\Floating_Plants_water.v6i.coco-segmentation\runs\water_segmentation\weights\best.pt"
model = YOLO(model_path)

# 設定測試圖片資料夾和結果輸出資料夾
test_folder = r"C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto"
output_folder = r"C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_results"
mask_output_folder = r"C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_masks"
json_output_folder = r"C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_segmentation"

# 確保輸出資料夾存在
os.makedirs(output_folder, exist_ok=True)
os.makedirs(mask_output_folder, exist_ok=True)
os.makedirs(json_output_folder, exist_ok=True)

# 取得所有圖片檔案
image_files = list(Path(test_folder).glob("*.jpg")) + list(Path(test_folder).glob("*.JPG")) + list(Path(test_folder).glob("*.png"))
print(f"找到 {len(image_files)} 張圖片")

# 記錄開始時間
start_time = time.time()

# 處理每張圖片
for i, img_path in enumerate(image_files):
    print(f"處理圖片 {i+1}/{len(image_files)}: {img_path.name}")
    
    # 讀取原始圖片以獲取尺寸
    original_img = cv2.imread(str(img_path))
    img_height, img_width = original_img.shape[:2]
    
    # 進行預測
    results = model(img_path, conf=0.25, iou=0.45)
    
    # 儲存結果圖片
    output_path = Path(output_folder) / f"result_{img_path.name}"
    results[0].save(str(output_path))
    
    # 建立 instance segmentation 結果的 JSON 資料
    segmentation_data = {
        "filename": img_path.name,
        "width": img_width,
        "height": img_height,
        "instances": []
    }
    
    # 檢查是否有檢測到物件
    if results[0].masks is not None:
        masks = results[0].masks
        boxes = results[0].boxes
        
        # 處理每個檢測到的物件
        for j, (mask, box) in enumerate(zip(masks, boxes)):
            # 獲取分類和信心度
            cls = int(box.cls.item())
            conf = float(box.conf.item())
            class_name = results[0].names[cls]
            
            # 獲取遮罩資料
            mask_array = mask.data.cpu().numpy()[0]  # 取得 numpy 陣列
            
            # 儲存遮罩圖片
            mask_output_path = Path(mask_output_folder) / f"{img_path.stem}_mask_{j}.png"
            cv2.imwrite(str(mask_output_path), (mask_array * 255).astype(np.uint8))
            
            # 獲取輪廓
            contours = []
            binary_mask = (mask_array > 0.5).astype(np.uint8)
            opencv_contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            # 轉換輪廓為多邊形格式
            for contour in opencv_contours:
                # 簡化輪廓點
                epsilon = 0.005 * cv2.arcLength(contour, True)
                approx = cv2.approxPolyDP(contour, epsilon, True)
                
                # 轉換為 [x1, y1, x2, y2, ...] 格式
                flattened = approx.flatten().tolist()
                if len(flattened) >= 6:  # 至少需要 3 個點 (6 個座標)
                    contours.append(flattened)
            
            # 計算面積
            area = float(cv2.contourArea(opencv_contours[0]) if opencv_contours else 0)
            
            # 獲取邊界框
            x1, y1, x2, y2 = box.xyxy.cpu().numpy()[0]
            bbox = [float(x1), float(y1), float(x2-x1), float(y2-y1)]  # [x, y, width, height]
            
            # 添加到 instance 資料
            instance = {
                "id": j,
                "category_id": cls,
                "category_name": class_name,
                "confidence": conf,
                "bbox": bbox,
                "area": area,
                "segmentation": contours
            }
            segmentation_data["instances"].append(instance)
        
        print(f"  ✓ 檢測到 {len(masks)} 個物件")
    else:
        print(f"  ✗ 未檢測到物件")
    
    # 儲存 JSON 檔案
    json_output_path = Path(json_output_folder) / f"{img_path.stem}_segmentation.json"
    with open(json_output_path, 'w', encoding='utf-8') as f:
        json.dump(segmentation_data, f, indent=2, ensure_ascii=False)

# 計算總處理時間
elapsed_time = time.time() - start_time
print(f"\n完成處理 {len(image_files)} 張圖片，耗時 {elapsed_time:.2f} 秒")
print(f"結果已儲存至:")
print(f"- 標註圖片: {output_folder}")
print(f"- 遮罩圖片: {mask_output_folder}")
print(f"- 分割資料: {json_output_folder}")
# Out:
# 找到 838 張圖片
# 處理圖片 1/838: A1_20250402.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250402.JPG: 480x640 2 water-plantss, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 2/838: A1_20250406.jpg
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250406.jpg: 480x640 2 water-plantss, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 3/838: A1_20250409.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250409.JPG: 480x640 2 water-plantss, 5.8ms
# Speed: 1.9ms preprocess, 5.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 4/838: A1_20250410.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250410.JPG: 480x640 5 water-plantss, 5.0ms
# Speed: 2.2ms preprocess, 5.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 5/838: A1_20250411.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250411.JPG: 480x640 5 water-plantss, 4.8ms
# Speed: 2.1ms preprocess, 4.8ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 6/838: A1_20250412.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250412.JPG: 480x640 2 water-plantss, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 7/838: A1_20250413.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250413.JPG: 640x480 2 water-plantss, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 2 個物件
# 處理圖片 8/838: A1_20250414.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250414.JPG: 640x480 2 water-plantss, 19.3ms
# Speed: 3.4ms preprocess, 19.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 2 個物件
# 處理圖片 9/838: A1_20250415.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250415.JPG: 640x480 2 water-plantss, 20.0ms
# Speed: 2.9ms preprocess, 20.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 2 個物件
# 處理圖片 10/838: A1_20250416.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250416.JPG: 640x480 2 water-plantss, 22.8ms
# Speed: 2.9ms preprocess, 22.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 2 個物件
# 處理圖片 11/838: A1_20250417.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250417.JPG: 480x640 2 water-plantss, 46.4ms
# Speed: 3.8ms preprocess, 46.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 12/838: A1_20250418.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250418.JPG: 480x640 2 water-plantss, 44.2ms
# Speed: 12.2ms preprocess, 44.2ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 13/838: A1_20250419.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\A1_20250419.JPG: 480x640 2 water-plantss, 48.0ms
# Speed: 3.6ms preprocess, 48.0ms inference, 13.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 14/838: A1_20250420.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\
ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 113/838: B1_20250414.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250414.JPG: 640x480 4 water-plantss, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 114/838: B1_20250415.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250415.JPG: 480x640 3 water-plantss, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 115/838: B1_20250416.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250416.JPG: 480x640 3 water-plantss, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 116/838: B1_20250417.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250417.JPG: 480x640 3 water-plantss, 47.1ms
# Speed: 3.5ms preprocess, 47.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 117/838: B1_20250418.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250418.JPG: 480x640 3 water-plantss, 40.6ms
# Speed: 3.7ms preprocess, 40.6ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 118/838: B1_20250419.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250419.JPG: 480x640 3 water-plantss, 40.4ms
# Speed: 3.8ms preprocess, 40.4ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 119/838: B1_20250420.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250420.JPG: 480x640 3 water-plantss, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 120/838: B1_20250421.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250421.JPG: 480x640 3 water-plantss, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 121/838: B1_20250422.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250422.JPG: 640x480 3 water-plantss, 16.5ms
# Speed: 2.6ms preprocess, 16.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 122/838: B1_20250423.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250423.JPG: 480x640 3 water-plantss, 14.2ms
# Speed: 2.8ms preprocess, 14.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 123/838: B1_20250424.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250424.JPG: 480x640 3 water-plantss, 16.1ms
# Speed: 2.4ms preprocess, 16.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 124/838: B1_20250426.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250426.JPG: 480x640 3 water-plantss, 49.3ms
# Speed: 4.3ms preprocess, 49.3ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 125/838: B1_20250427.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250427.JPG: 480x640 3 water-plantss, 50.3ms
# Speed: 4.0ms preprocess, 50.3ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 126/838: B1_20250428.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250428.JPG: 480x640 3 water-plantss, 66.4ms
# Speed: 3.9ms preprocess, 66.4ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 127/838: B1_20250429.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250429.JPG: 640x480 3 water-plantss, 44.2ms
# Speed: 3.4ms preprocess, 44.2ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 128/838: B1_20250430.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250430.JPG: 480x640 5 water-plantss, 46.4ms
# Speed: 3.4ms preprocess, 46.4ms inference, 18.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 129/838: B1_20250501.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250501.JPG: 480x640 3 water-plantss, 37.6ms
# Speed: 4.0ms preprocess, 37.6ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 130/838: B1_20250502.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250502.JPG: 480x640 3 water-plantss, 42.6ms
# Speed: 3.6ms preprocess, 42.6ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 131/838: B1_20250503.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250503.JPG: 480x640 3 water-plantss, 16.9ms
# Speed: 2.7ms preprocess, 16.9ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 132/838: B1_20250504.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250504.JPG: 480x640 3 water-plantss, 15.1ms
# Speed: 2.9ms preprocess, 15.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 133/838: B1_20250505.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250505.JPG: 480x640 3 water-plantss, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 134/838: B1_20250506.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250506.JPG: 480x640 4 water-plantss, 14.8ms
# Speed: 2.8ms preprocess, 14.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 135/838: B1_20250507.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250507.JPG: 480x640 4 water-plantss, 21.2ms
# Speed: 2.7ms preprocess, 21.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 136/838: B1_20250508.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250508.JPG: 480x640 4 water-plantss, 49.7ms
# Speed: 12.6ms preprocess, 49.7ms inference, 16.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 137/838: B1_20250509.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250509.JPG: 640x480 4 water-plantss, 49.7ms
# Speed: 3.7ms preprocess, 49.7ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 138/838: B1_20250510.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250510.JPG: 480x640 3 water-plantss, 45.3ms
# Speed: 9.9ms preprocess, 45.3ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 139/838: B1_20250511.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250511.JPG: 480x640 3 water-plantss, 16.5ms
# Speed: 2.9ms preprocess, 16.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 140/838: B1_20250512.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B1_20250512.JPG: 480x640 4 water-plantss, 17.5ms
# Speed: 2.8ms preprocess, 17.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 141/838: B2_20250402.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250402.JPG: 480x640 8 water-plantss, 17.4ms
# Speed: 2.9ms preprocess, 17.4ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 142/838: B2_20250406.jpg
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250406.jpg: 480x640 6 water-plantss, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 143/838: B2_20250409.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250409.JPG: 480x640 6 water-plantss, 16.7ms
# Speed: 2.8ms preprocess, 16.7ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 144/838: B2_20250410.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250410.JPG: 480x640 8 water-plantss, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 145/838: B2_20250411.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250411.JPG: 480x640 8 water-plantss, 48.0ms
# Speed: 3.6ms preprocess, 48.0ms inference, 26.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 146/838: B2_20250412.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250412.JPG: 480x640 5 water-plantss, 51.9ms
# Speed: 3.3ms preprocess, 51.9ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 147/838: B2_20250413.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250413.JPG: 480x640 8 water-plantss, 57.7ms
# Speed: 3.8ms preprocess, 57.7ms inference, 27.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 148/838: B2_20250414.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250414.JPG: 640x480 7 water-plantss, 22.7ms
# Speed: 3.1ms preprocess, 22.7ms inference, 12.8ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 7 個物件
# 處理圖片 149/838: B2_20250415.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250415.JPG: 640x480 7 water-plantss, 16.7ms
# Speed: 3.9ms preprocess, 16.7ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 7 個物件
# 處理圖片 150/838: B2_20250416.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250416.JPG: 640x480 7 water-plantss, 17.6ms
# Speed: 2.9ms preprocess, 17.6ms inference, 11.2ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 7 個物件
# 處理圖片 151/838: B2_20250417.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250417.JPG: 480x640 8 water-plantss, 18.3ms
# Speed: 3.1ms preprocess, 18.3ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 152/838: B2_20250418.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250418.JPG: 480x640 8 water-plantss, 62.2ms
# Speed: 3.6ms preprocess, 62.2ms inference, 15.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 153/838: B2_20250419.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250419.JPG: 480x640 6 water-plantss, 43.2ms
# Speed: 4.1ms preprocess, 43.2ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 154/838: B2_20250420.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250420.JPG: 480x640 6 water-plantss, 46.7ms
# Speed: 4.8ms preprocess, 46.7ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 155/838: B2_20250421.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250421.JPG: 480x640 4 water-plantss, 52.9ms
# Speed: 3.9ms preprocess, 52.9ms inference, 13.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 156/838: B2_20250422.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250422.JPG: 640x480 8 water-plantss, 37.9ms
# Speed: 5.4ms preprocess, 37.9ms inference, 18.5ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 8 個物件
# 處理圖片 157/838: B2_20250423.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250423.JPG: 480x640 7 water-plantss, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 7 個物件
# 處理圖片 158/838: B2_20250424.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250424.JPG: 480x640 6 water-plantss, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 159/838: B2_20250426.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250426.JPG: 480x640 6 water-plantss, 16.2ms
# Speed: 3.5ms preprocess, 16.2ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 160/838: B2_20250427.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250427.JPG: 480x640 5 water-plantss, 16.4ms
# Speed: 2.8ms preprocess, 16.4ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 161/838: B2_20250428.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250428.JPG: 480x640 7 water-plantss, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 7 個物件
# 處理圖片 162/838: B2_20250429.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250429.JPG: 640x480 7 water-plantss, 68.0ms
# Speed: 3.6ms preprocess, 68.0ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 7 個物件
# 處理圖片 163/838: B2_20250430.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250430.JPG: 480x640 8 water-plantss, 47.4ms
# Speed: 3.6ms preprocess, 47.4ms inference, 17.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 164/838: B2_20250501.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250501.JPG: 480x640 10 water-plantss, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 10 個物件
# 處理圖片 165/838: B2_20250502.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250502.JPG: 480x640 9 water-plantss, 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 9 個物件
# 處理圖片 166/838: B2_20250503.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250503.JPG: 480x640 6 water-plantss, 17.1ms
# Speed: 2.9ms preprocess, 17.1ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 167/838: B2_20250504.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250504.JPG: 480x640 6 water-plantss, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 168/838: B2_20250505.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250505.JPG: 480x640 8 water-plantss, 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 11.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 169/838: B2_20250506.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250506.JPG: 480x640 11 water-plantss, 48.4ms
# Speed: 13.7ms preprocess, 48.4ms inference, 19.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 11 個物件
# 處理圖片 170/838: B2_20250507.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250507.JPG: 480x640 5 water-plantss, 36.6ms
# Speed: 7.6ms preprocess, 36.6ms inference, 15.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 171/838: B2_20250508.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250508.JPG: 480x640 9 water-plantss, 14.8ms
# Speed: 2.9ms preprocess, 14.8ms inference, 15.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 9 個物件
# 處理圖片 172/838: B2_20250509.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250509.JPG: 640x480 8 water-plantss, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 8 個物件
# 處理圖片 173/838: B2_20250510.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250510.JPG: 480x640 7 water-plantss, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 12.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 7 個物件
# 處理圖片 174/838: B2_20250511.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250511.JPG: 480x640 6 water-plantss, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 175/838: B2_20250512.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B2_20250512.JPG: 480x640 7 water-plantss, 17.3ms
# Speed: 3.0ms preprocess, 17.3ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 7 個物件
# 處理圖片 176/838: B3_20250402.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250402.JPG: 640x480 6 water-plantss, 64.6ms
# Speed: 3.6ms preprocess, 64.6ms inference, 16.6ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 6 個物件
# 處理圖片 177/838: B3_20250406.jpg
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250406.jpg: 480x640 3 water-plantss, 53.2ms
# Speed: 3.1ms preprocess, 53.2ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 178/838: B3_20250409.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250409.JPG: 480x640 4 water-plantss, 17.8ms
# Speed: 3.0ms preprocess, 17.8ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 179/838: B3_20250410.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250410.JPG: 480x640 6 water-plantss, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 180/838: B3_20250411.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250411.JPG: 480x640 6 water-plantss, 14.4ms
# Speed: 2.9ms preprocess, 14.4ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 181/838: B3_20250412.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250412.JPG: 480x640 4 water-plantss, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 182/838: B3_20250413.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250413.JPG: 480x640 4 water-plantss, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 183/838: B3_20250414.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250414.JPG: 640x480 3 water-plantss, 17.5ms
# Speed: 3.8ms preprocess, 17.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 184/838: B3_20250415.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250415.JPG: 640x480 6 water-plantss, 46.2ms
# Speed: 3.8ms preprocess, 46.2ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 6 個物件
# 處理圖片 185/838: B3_20250416.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250416.JPG: 640x480 6 water-plantss, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 6 個物件
# 處理圖片 186/838: B3_20250417.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250417.JPG: 480x640 3 water-plantss, 19.2ms
# Speed: 3.8ms preprocess, 19.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 187/838: B3_20250418.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250418.JPG: 480x640 4 water-plantss, 15.1ms
# Speed: 2.8ms preprocess, 15.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 188/838: B3_20250419.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250419.JPG: 480x640 4 water-plantss, 15.2ms
# Speed: 2.6ms preprocess, 15.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 189/838: B3_20250420.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250420.JPG: 480x640 3 water-plantss, 17.7ms
# Speed: 2.9ms preprocess, 17.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 190/838: B3_20250421.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250421.JPG: 480x640 4 water-plantss, 48.5ms
# Speed: 3.7ms preprocess, 48.5ms inference, 15.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 191/838: B3_20250422.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250422.JPG: 640x480 4 water-plantss, 52.7ms
# Speed: 6.8ms preprocess, 52.7ms inference, 14.1ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 192/838: B3_20250423.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250423.JPG: 480x640 4 water-plantss, 40.5ms
# Speed: 7.8ms preprocess, 40.5ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 193/838: B3_20250424.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250424.JPG: 480x640 5 water-plantss, 36.5ms
# Speed: 9.4ms preprocess, 36.5ms inference, 19.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 194/838: B3_20250426.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250426.JPG: 480x640 3 water-plantss, 36.5ms
# Speed: 3.7ms preprocess, 36.5ms inference, 17.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 195/838: B3_20250427.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250427.JPG: 480x640 5 water-plantss, 42.4ms
# Speed: 7.8ms preprocess, 42.4ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 196/838: B3_20250428.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\B3_20250428.JPG: 480x640 5 water-plantss, 45.1ms
# Speed: 3.6ms preprocess, 45.1ms inference, 17.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# ...
# Speed: 4.0ms preprocess, 37.5ms inference, 22.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 8 個物件
# 處理圖片 775/838: D2_20250413.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250413.JPG: 480x640 3 water-plantss, 17.6ms
# Speed: 2.9ms preprocess, 17.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 776/838: D2_20250414.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250414.JPG: 640x480 3 water-plantss, 20.7ms
# Speed: 2.6ms preprocess, 20.7ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 777/838: D2_20250415.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250415.JPG: 640x480 4 water-plantss, 17.6ms
# Speed: 4.1ms preprocess, 17.6ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 778/838: D2_20250416.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250416.JPG: 640x480 4 water-plantss, 16.4ms
# Speed: 2.7ms preprocess, 16.4ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 779/838: D2_20250417.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250417.JPG: 480x640 4 water-plantss, 18.4ms
# Speed: 3.2ms preprocess, 18.4ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 780/838: D2_20250418.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250418.JPG: 480x640 4 water-plantss, 34.6ms
# Speed: 3.8ms preprocess, 34.6ms inference, 13.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 781/838: D2_20250419.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250419.JPG: 480x640 3 water-plantss, 57.1ms
# Speed: 4.7ms preprocess, 57.1ms inference, 14.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 782/838: D2_20250420.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250420.JPG: 480x640 3 water-plantss, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 783/838: D2_20250421.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250421.JPG: 480x640 2 water-plantss, 14.6ms
# Speed: 2.9ms preprocess, 14.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 784/838: D2_20250422.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250422.JPG: 640x480 3 water-plantss, 14.8ms
# Speed: 2.8ms preprocess, 14.8ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 785/838: D2_20250423.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250423.JPG: 480x640 4 water-plantss, 14.6ms
# Speed: 2.8ms preprocess, 14.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 786/838: D2_20250424.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250424.JPG: 480x640 4 water-plantss, 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 787/838: D2_20250426.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250426.JPG: 480x640 4 water-plantss, 38.6ms
# Speed: 4.0ms preprocess, 38.6ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 788/838: D2_20250427.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250427.JPG: 480x640 3 water-plantss, 32.2ms
# Speed: 3.9ms preprocess, 32.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 789/838: D2_20250428.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250428.JPG: 480x640 3 water-plantss, 51.5ms
# Speed: 3.8ms preprocess, 51.5ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 790/838: D2_20250429.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250429.JPG: 640x480 3 water-plantss, 30.6ms
# Speed: 4.3ms preprocess, 30.6ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 791/838: D2_20250430.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250430.JPG: 480x640 6 water-plantss, 50.2ms
# Speed: 3.9ms preprocess, 50.2ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 792/838: D2_20250501.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250501.JPG: 480x640 4 water-plantss, 36.2ms
# Speed: 3.8ms preprocess, 36.2ms inference, 12.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 793/838: D2_20250502.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250502.JPG: 480x640 5 water-plantss, 41.1ms
# Speed: 4.0ms preprocess, 41.1ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 794/838: D2_20250503.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250503.JPG: 480x640 3 water-plantss, 41.9ms
# Speed: 8.2ms preprocess, 41.9ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 795/838: D2_20250504.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250504.JPG: 480x640 3 water-plantss, 61.4ms
# Speed: 4.2ms preprocess, 61.4ms inference, 14.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 796/838: D2_20250505.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250505.JPG: 480x640 3 water-plantss, 19.9ms
# Speed: 3.9ms preprocess, 19.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 797/838: D2_20250506.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250506.JPG: 480x640 4 water-plantss, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 798/838: D2_20250507.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250507.JPG: 480x640 5 water-plantss, 17.2ms
# Speed: 3.2ms preprocess, 17.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 799/838: D2_20250508.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250508.JPG: 480x640 5 water-plantss, 17.7ms
# Speed: 2.8ms preprocess, 17.7ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 5 個物件
# 處理圖片 800/838: D2_20250509.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250509.JPG: 640x480 6 water-plantss, 18.0ms
# Speed: 3.4ms preprocess, 18.0ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 6 個物件
# 處理圖片 801/838: D2_20250510.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250510.JPG: 480x640 4 water-plantss, 47.5ms
# Speed: 5.2ms preprocess, 47.5ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 802/838: D2_20250511.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D2_20250511.JPG: 640x480 4 water-plantss, 63.6ms
# Speed: 4.0ms preprocess, 63.6ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 803/838: D2_20250512.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\
JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250427.JPG: 480x640 2 water-plantss, 32.2ms
# Speed: 4.1ms preprocess, 32.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 824/838: D3_20250428.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250428.JPG: 480x640 3 water-plantss, 31.9ms
# Speed: 4.2ms preprocess, 31.9ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 825/838: D3_20250429.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250429.JPG: 640x480 5 water-plantss, 33.9ms
# Speed: 4.6ms preprocess, 33.9ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 5 個物件
# 處理圖片 826/838: D3_20250430.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250430.JPG: 480x640 6 water-plantss, 39.0ms
# Speed: 4.6ms preprocess, 39.0ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 6 個物件
# 處理圖片 827/838: D3_20250501.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250501.JPG: 480x640 2 water-plantss, 37.6ms
# Speed: 3.7ms preprocess, 37.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 828/838: D3_20250502.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250502.JPG: 640x480 3 water-plantss, 46.0ms
# Speed: 10.2ms preprocess, 46.0ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 829/838: D3_20250503.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250503.JPG: 480x640 2 water-plantss, 39.3ms
# Speed: 4.4ms preprocess, 39.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 830/838: D3_20250504.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250504.JPG: 480x640 2 water-plantss, 37.3ms
# Speed: 3.8ms preprocess, 37.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 831/838: D3_20250505.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250505.JPG: 480x640 3 water-plantss, 55.9ms
# Speed: 5.0ms preprocess, 55.9ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 832/838: D3_20250506.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250506.JPG: 480x640 4 water-plantss, 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 833/838: D3_20250507.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250507.JPG: 480x640 3 water-plantss, 14.8ms
# Speed: 2.8ms preprocess, 14.8ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
# 處理圖片 834/838: D3_20250508.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250508.JPG: 640x480 3 water-plantss, 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 3 個物件
# 處理圖片 835/838: D3_20250509.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250509.JPG: 640x480 4 water-plantss, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
#   ✓ 檢測到 4 個物件
# 處理圖片 836/838: D3_20250510.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250510.JPG: 480x640 4 water-plantss, 29.9ms
# Speed: 2.8ms preprocess, 29.9ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 4 個物件
# 處理圖片 837/838: D3_20250511.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250511.JPG: 480x640 2 water-plantss, 32.4ms
# Speed: 3.9ms preprocess, 32.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 2 個物件
# 處理圖片 838/838: D3_20250512.JPG
#
# image 1/1 C:\Users\hanaj\Desktop\HanaJ\Lab\PlantPhoto\D3_20250512.JPG: 480x640 3 water-plantss, 44.8ms
# Speed: 3.4ms preprocess, 44.8ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#   ✓ 檢測到 3 個物件
#
# 完成處理 838 張圖片，耗時 305.18 秒
# 結果已儲存至:
# - 標註圖片: C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_results
# - 遮罩圖片: C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_masks
# - 分割資料: C:\Users\hanaj\Desktop\HanaJ\Lab\cropped_segmentation
